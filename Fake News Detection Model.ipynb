# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import preprocessing
import keras
import tensorflow as tf

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd
import json
import csv
import random

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import regularizers

import pprint
import tensorflow.compat.v1 as tf
from tensorflow.python.framework import ops
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
tf.disable_eager_execution()

# Reading the data
data = pd.read_csv("/content/drive/MyDrive/news.csv")
data.head()
# Out:
#    Unnamed: 0                                              title  \
# 0        8476                       You Can Smell Hillary’s Fear
# 1       10294  Watch The Exact Moment Paul Ryan Committed Pol...
# 2        3608        Kerry to go to Paris in gesture of sympathy
# 3       10142  Bernie supporters on Twitter erupt in anger ag...
# 4         875   The Battle of New York: Why This Primary Matters
#
#                                                 text label
# 0  Daniel Greenfield, a Shillman Journalism Fello...  FAKE
# 1  Google Pinterest Digg Linkedin Reddit Stumbleu...  FAKE
# 2  U.S. Secretary of State John F. Kerry said Mon...  REAL
# 3  — Kaydee King (@KaydeeKing) November 9, 2016 T...  FAKE
# 4  It's primary day in New York and front-runners...  REAL

# %%
data = data.drop(["Unnamed: 0"], axis=1)
data.head(5)
# Out:
#                                                title  \
# 0                       You Can Smell Hillary’s Fear
# 1  Watch The Exact Moment Paul Ryan Committed Pol...
# 2        Kerry to go to Paris in gesture of sympathy
# 3  Bernie supporters on Twitter erupt in anger ag...
# 4   The Battle of New York: Why This Primary Matters
#
#                                                 text label
# 0  Daniel Greenfield, a Shillman Journalism Fello...  FAKE
# 1  Google Pinterest Digg Linkedin Reddit Stumbleu...  FAKE
# 2  U.S. Secretary of State John F. Kerry said Mon...  REAL
# 3  — Kaydee King (@KaydeeKing) November 9, 2016 T...  FAKE
# 4  It's primary day in New York and front-runners...  REAL

# %%
# encoding the labels
le = preprocessing.LabelEncoder()
le.fit(data['label'])
data['label'] = le.transform(data['label'])

# %%
embedding_dim = 50
max_length = 54
trunc_type = 'post'
padding_type = 'post'
oov_tok = "<OOV>"
training_size = 3000
test_portion = .1

# %%
title = []
text = []
labels = []
for x in range(training_size):
	title.append(data['title'][x])
	text.append(data['text'][x])
	labels.append(data['label'][x])

# %%
tokenizer1 = Tokenizer()
tokenizer1.fit_on_texts(title)
word_index1 = tokenizer1.word_index
vocab_size1 = len(word_index1)
sequences1 = tokenizer1.texts_to_sequences(title)
padded1 = pad_sequences(
	sequences1, padding=padding_type, truncating=trunc_type)
split = int(test_portion * training_size)
training_sequences1 = padded1[split:training_size]
test_sequences1 = padded1[0:split]
test_labels = labels[0:split]
training_labels = labels[split:training_size]

# %%
embeddings_index = {}
with open('/content/drive/MyDrive/glove.6B.50d.txt') as f:
	for line in f:
		values = line.split()
		word = values[0]
		coefs = np.asarray(values[1:], dtype='float32')
		embeddings_index[word] = coefs

# Generating embeddings
embeddings_matrix = np.zeros((vocab_size1+1, embedding_dim))
for word, i in word_index1.items():
	embedding_vector = embeddings_index.get(word)
	if embedding_vector is not None:
		embeddings_matrix[i] = embedding_vector

# %%
model = tf.keras.Sequential([
	tf.keras.layers.Embedding(vocab_size1+1, embedding_dim,
							input_length=max_length, weights=[
								embeddings_matrix],
							trainable=False),
	tf.keras.layers.Dropout(0.2),
	tf.keras.layers.Conv1D(64, 5, activation='relu'),
	tf.keras.layers.MaxPooling1D(pool_size=4),
	tf.keras.layers.LSTM(64),
	tf.keras.layers.Dense(1, activation='sigmoid')
])
model.compile(loss='binary_crossentropy',
			optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 54, 50)            377600
#
#  dropout (Dropout)           (None, 54, 50)            0
#
#  conv1d (Conv1D)             (None, 50, 64)            16064
#
#  max_pooling1d (MaxPooling1  (None, 12, 64)            0
#  D)
#
#  lstm (LSTM)                 (None, 64)                33024
#
#  dense (Dense)               (None, 1)                 65
#
# =================================================================
# Total params: 426753 (1.63 MB)
# Trainable params: 49153 (192.00 KB)
# Non-trainable params: 377600 (1.44 MB)
# _________________________________________________________________

# %%
num_epochs = 50

training_padded = np.array(training_sequences1)
training_labels = np.array(training_labels)
testing_padded = np.array(test_sequences1)
testing_labels = np.array(test_labels)

history = model.fit(training_padded, training_labels,
					epochs=num_epochs,
					validation_data=(testing_padded,
									testing_labels),
					verbose=2)
# Out:
# Train on 2700 samples, validate on 300 samples
# Epoch 1/50
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training_v1.py:2335: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates = self.state_updates
# 2700/2700 - 3s - loss: 0.6441 - accuracy: 0.6107 - val_loss: 0.5996 - val_accuracy: 0.6500 - 3s/epoch - 927us/sample
# Epoch 2/50
# 2700/2700 - 2s - loss: 0.5761 - accuracy: 0.7011 - val_loss: 0.5485 - val_accuracy: 0.7000 - 2s/epoch - 665us/sample
# Epoch 3/50
# 2700/2700 - 2s - loss: 0.5268 - accuracy: 0.7385 - val_loss: 0.5419 - val_accuracy: 0.7333 - 2s/epoch - 905us/sample
# Epoch 4/50
# 2700/2700 - 3s - loss: 0.5002 - accuracy: 0.7544 - val_loss: 0.5203 - val_accuracy: 0.7500 - 3s/epoch - 1ms/sample
# Epoch 5/50
# 2700/2700 - 2s - loss: 0.4377 - accuracy: 0.7878 - val_loss: 0.5098 - val_accuracy: 0.7300 - 2s/epoch - 667us/sample
# Epoch 6/50
# 2700/2700 - 2s - loss: 0.4011 - accuracy: 0.8248 - val_loss: 0.4969 - val_accuracy: 0.7600 - 2s/epoch - 663us/sample
# Epoch 7/50
# 2700/2700 - 2s - loss: 0.3277 - accuracy: 0.8574 - val_loss: 0.4966 - val_accuracy: 0.7567 - 2s/epoch - 653us/sample
# Epoch 8/50
# 2700/2700 - 2s - loss: 0.3130 - accuracy: 0.8685 - val_loss: 0.5178 - val_accuracy: 0.7600 - 2s/epoch - 645us/sample
# Epoch 9/50
# 2700/2700 - 2s - loss: 0.2894 - accuracy: 0.8837 - val_loss: 0.6831 - val_accuracy: 0.7133 - 2s/epoch - 678us/sample
# Epoch 10/50
# 2700/2700 - 3s - loss: 0.2525 - accuracy: 0.8937 - val_loss: 0.5726 - val_accuracy: 0.7333 - 3s/epoch - 1ms/sample
# Epoch 11/50
# 2700/2700 - 3s - loss: 0.2733 - accuracy: 0.8859 - val_loss: 0.5493 - val_accuracy: 0.7667 - 3s/epoch - 1ms/sample
# Epoch 12/50
# 2700/2700 - 2s - loss: 0.2096 - accuracy: 0.9152 - val_loss: 0.6005 - val_accuracy: 0.7600 - 2s/epoch - 679us/sample
# Epoch 13/50
# 2700/2700 - 2s - loss: 0.1938 - accuracy: 0.9204 - val_loss: 0.5931 - val_accuracy: 0.7500 - 2s/epoch - 659us/sample
# Epoch 14/50
# 2700/2700 - 2s - loss: 0.1965 - accuracy: 0.9159 - val_loss: 0.6083 - val_accuracy: 0.7567 - 2s/epoch - 622us/sample
# Epoch 15/50
# 2700/2700 - 2s - loss: 0.1807 - accuracy: 0.9289 - val_loss: 0.7278 - val_accuracy: 0.7633 - 2s/epoch - 640us/sample
# Epoch 16/50
# 2700/2700 - 2s - loss: 0.1762 - accuracy: 0.9315 - val_loss: 0.6086 - val_accuracy: 0.7600 - 2s/epoch - 635us/sample
# Epoch 17/50
# 2700/2700 - 3s - loss: 0.1277 - accuracy: 0.9456 - val_loss: 0.6695 - val_accuracy: 0.7467 - 3s/epoch - 1ms/sample
# Epoch 18/50
# 2700/2700 - 3s - loss: 0.1408 - accuracy: 0.9393 - val_loss: 0.7545 - val_accuracy: 0.7600 - 3s/epoch - 1ms/sample
# Epoch 19/50
# 2700/2700 - 2s - loss: 0.1420 - accuracy: 0.9444 - val_loss: 1.0778 - val_accuracy: 0.6967 - 2s/epoch - 629us/sample
# Epoch 20/50
# 2700/2700 - 2s - loss: 0.1168 - accuracy: 0.9567 - val_loss: 0.6554 - val_accuracy: 0.7633 - 2s/epoch - 623us/sample
# Epoch 21/50
# 2700/2700 - 2s - loss: 0.1174 - accuracy: 0.9537 - val_loss: 0.7525 - val_accuracy: 0.7533 - 2s/epoch - 634us/sample
# Epoch 22/50
# 2700/2700 - 2s - loss: 0.1138 - accuracy: 0.9570 - val_loss: 0.8013 - val_accuracy: 0.7467 - 2s/epoch - 620us/sample
# Epoch 23/50
# 2700/2700 - 2s - loss: 0.1184 - accuracy: 0.9589 - val_loss: 0.7857 - val_accuracy: 0.7467 - 2s/epoch - 639us/sample
# Epoch 24/50
# 2700/2700 - 3s - loss: 0.1147 - accuracy: 0.9567 - val_loss: 0.7347 - val_accuracy: 0.7700 - 3s/epoch - 1ms/sample
# Epoch 25/50
# 2700/2700 - 2s - loss: 0.0987 - accuracy: 0.9619 - val_loss: 0.8771 - val_accuracy: 0.7300 - 2s/epoch - 819us/sample
# Epoch 26/50
# 2700/2700 - 2s - loss: 0.1092 - accuracy: 0.9578 - val_loss: 0.6430 - val_accuracy: 0.7667 - 2s/epoch - 647us/sample
# Epoch 27/50
# 2700/2700 - 2s - loss: 0.1171 - accuracy: 0.9596 - val_loss: 0.7901 - val_accuracy: 0.7533 - 2s/epoch - 638us/sample
# Epoch 28/50
# 2700/2700 - 2s - loss: 0.1091 - accuracy: 0.9578 - val_loss: 0.7527 - val_accuracy: 0.7633 - 2s/epoch - 642us/sample
# Epoch 29/50
# 2700/2700 - 2s - loss: 0.0780 - accuracy: 0.9741 - val_loss: 0.8150 - val_accuracy: 0.7500 - 2s/epoch - 660us/sample
# Epoch 30/50
# 2700/2700 - 2s - loss: 0.0604 - accuracy: 0.9748 - val_loss: 0.9014 - val_accuracy: 0.7567 - 2s/epoch - 647us/sample
# Epoch 31/50
# 2700/2700 - 3s - loss: 0.0766 - accuracy: 0.9759 - val_loss: 0.9156 - val_accuracy: 0.7633 - 3s/epoch - 1ms/sample
# Epoch 32/50
# 2700/2700 - 2s - loss: 0.0795 - accuracy: 0.9726 - val_loss: 0.8827 - val_accuracy: 0.7433 - 2s/epoch - 756us/sample
# Epoch 33/50
# 2700/2700 - 2s - loss: 0.0948 - accuracy: 0.9626 - val_loss: 0.7016 - val_accuracy: 0.7633 - 2s/epoch - 636us/sample
# Epoch 34/50
# 2700/2700 - 2s - loss: 0.0779 - accuracy: 0.9733 - val_loss: 0.7042 - val_accuracy: 0.7600 - 2s/epoch - 637us/sample
# Epoch 35/50
# 2700/2700 - 2s - loss: 0.0838 - accuracy: 0.9711 - val_loss: 0.7804 - val_accuracy: 0.7633 - 2s/epoch - 597us/sample
# Epoch 36/50
# 2700/2700 - 2s - loss: 0.0745 - accuracy: 0.9741 - val_loss: 0.8309 - val_accuracy: 0.7667 - 2s/epoch - 632us/sample
# Epoch 37/50
# 2700/2700 - 2s - loss: 0.0640 - accuracy: 0.9767 - val_loss: 0.9677 - val_accuracy: 0.7567 - 2s/epoch - 592us/sample
# Epoch 38/50
# 2700/2700 - 3s - loss: 0.0935 - accuracy: 0.9644 - val_loss: 0.8303 - val_accuracy: 0.7633 - 3s/epoch - 963us/sample
# Epoch 39/50
# 2700/2700 - 2s - loss: 0.0759 - accuracy: 0.9667 - val_loss: 0.8644 - val_accuracy: 0.7800 - 2s/epoch - 915us/sample
# Epoch 40/50
# 2700/2700 - 2s - loss: 0.0680 - accuracy: 0.9767 - val_loss: 0.8057 - val_accuracy: 0.7733 - 2s/epoch - 608us/sample
# Epoch 41/50
# 2700/2700 - 2s - loss: 0.0647 - accuracy: 0.9770 - val_loss: 0.6634 - val_accuracy: 0.7800 - 2s/epoch - 609us/sample
# Epoch 42/50
# 2700/2700 - 2s - loss: 0.0737 - accuracy: 0.9707 - val_loss: 0.8955 - val_accuracy: 0.7433 - 2s/epoch - 636us/sample
# Epoch 43/50
# 2700/2700 - 2s - loss: 0.0645 - accuracy: 0.9748 - val_loss: 0.9076 - val_accuracy: 0.7333 - 2s/epoch - 639us/sample
# Epoch 44/50
# 2700/2700 - 2s - loss: 0.0883 - accuracy: 0.9678 - val_loss: 0.7282 - val_accuracy: 0.7600 - 2s/epoch - 627us/sample
# Epoch 45/50
# 2700/2700 - 2s - loss: 0.0565 - accuracy: 0.9822 - val_loss: 0.9340 - val_accuracy: 0.7767 - 2s/epoch - 775us/sample
# Epoch 46/50
# 2700/2700 - 3s - loss: 0.0663 - accuracy: 0.9737 - val_loss: 0.8748 - val_accuracy: 0.7533 - 3s/epoch - 1ms/sample
# Epoch 47/50
# 2700/2700 - 2s - loss: 0.0691 - accuracy: 0.9759 - val_loss: 1.0937 - val_accuracy: 0.7200 - 2s/epoch - 582us/sample
# Epoch 48/50
# 2700/2700 - 2s - loss: 0.0588 - accuracy: 0.9741 - val_loss: 0.9127 - val_accuracy: 0.7700 - 2s/epoch - 614us/sample
# Epoch 49/50
# 2700/2700 - 2s - loss: 0.0601 - accuracy: 0.9770 - val_loss: 0.8474 - val_accuracy: 0.7633 - 2s/epoch - 641us/sample
# Epoch 50/50
# 2700/2700 - 2s - loss: 0.0740 - accuracy: 0.9752 - val_loss: 0.7561 - val_accuracy: 0.7667 - 2s/epoch - 610us/sample

# %%
# sample text to check if fake or not
X = "Karry to go to France in gesture of sympathy"

# detection
sequences = tokenizer1.texts_to_sequences([X])[0]
sequences = pad_sequences([sequences], maxlen=54,
						padding=padding_type,
						truncating=trunc_type)
if(model.predict(sequences, verbose=0)[0][0] >= 0.5):
	print("This news is True")
else:
	print("This news is false")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training_v1.py:2359: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# This news is false
